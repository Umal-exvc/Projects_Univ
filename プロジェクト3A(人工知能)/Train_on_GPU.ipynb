# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/Transformer-master/
# Out:
# /content/drive/My Drive/Transformer-master

# %% [markdown]
# # ライブラリ読み込み

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblwp-mediatypes-perl libparse-debianchangelog-perl libsigc++-2.0-0v5
#   libsub-name-perl libtimedate-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 39 not upgraded.
# Need to get 3,877 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude-common all 0.8.10-6ubuntu1 [1,014 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcwidget3v5 amd64 0.5.17-7 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxapian30 amd64 1.4.5-1ubuntu0.1 [631 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude amd64 0.8.10-6ubuntu1 [1,269 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-pm-perl all 4.38-1 [185 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfcgi-perl amd64 0.78-2build1 [32.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-fast-perl all 1:2.13-1 [9,940 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsub-name-perl amd64 0.21-1build1 [11.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libparse-debianchangelog-perl all 1.2.0-12 [49.5 kB]
# Fetched 3,877 kB in 0s (23.9 MB/s)
# Selecting previously unselected package aptitude-common.
# (Reading database ... 160815 files and directories currently installed.)
# Preparing to unpack .../00-aptitude-common_0.8.10-6ubuntu1_all.deb ...
# Unpacking aptitude-common (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../01-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libcwidget3v5:amd64.
# Preparing to unpack .../02-libcwidget3v5_0.5.17-7_amd64.deb ...
# Unpacking libcwidget3v5:amd64 (0.5.17-7) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../03-libxapian30_1.4.5-1ubuntu0.1_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../04-aptitude_0.8.10-6ubuntu1_amd64.deb ...
# Unpacking aptitude (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../05-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../06-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../07-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../08-libcgi-pm-perl_4.38-1_all.deb ...
# Unpacking libcgi-pm-perl (4.38-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../09-libfcgi-perl_0.78-2build1_amd64.deb ...
# Unpacking libfcgi-perl (0.78-2build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../10-libcgi-fast-perl_1%3a2.13-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.13-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../11-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../12-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../13-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-12_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up aptitude-common (0.8.10-6ubuntu1) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libcgi-pm-perl (4.38-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libfcgi-perl (0.78-2build1) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libcgi-fast-perl (1:2.13-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libcwidget3v5:amd64 (0.5.17-7) ...
# Setting up aptitude (0.8.10-6ubuntu1) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# git is already installed at the requested version (1:2.17.1-1ubuntu0.8)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.13)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.8)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.13)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a} libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# 0 packages upgraded, 11 newly installed, 0 to remove and 39 not upgraded.
# Need to get 29.3 MB of archives. After unpacking 282 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get: 4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get: 5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab-dev amd64 0.996-5 [308 kB]
# Get: 6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-utils amd64 0.996-5 [4,856 B]
# Get: 7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-4 [16.2 MB]
# Get: 8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic all 7.0-20130310-4 [2,212 B]
# Get: 9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic all 2.7.0-20070801+main-1 [12.1 MB]
# Get: 10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab amd64 0.996-5 [132 kB]
# Get: 11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-1 [3,522 B]
# Fetched 29.3 MB in 1s (54.9 MB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 161274 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../04-libmecab-dev_0.996-5_amd64.deb ...
# Unpacking libmecab-dev (0.996-5) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../05-mecab-utils_0.996-5_amd64.deb ...
# Unpacking mecab-utils (0.996-5) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../06-mecab-jumandic-utf8_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-4) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../07-mecab-jumandic_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-4) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../08-mecab-ipadic_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../09-mecab_0.996-5_amd64.deb ...
# Unpacking mecab (0.996-5) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../10-mecab-ipadic-utf8_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Setting up libmecab2:amd64 (0.996-5) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up mecab-utils (0.996-5) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libmecab-dev (0.996-5) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up mecab-jumandic-utf8 (7.0-20130310-4) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-5) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic (7.0-20130310-4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
# Collecting mecab-python3==0.6
#   Downloading https://files.pythonhosted.org/packages/e3/7f/f98371035a0171abf95f9893eabf915f8a3199d005fed3cd69cc122fed40/mecab-python3-0.6.tar.gz (41kB)
#      |████████████████████████████████| 51kB 5.6MB/s
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.6-cp37-cp37m-linux_x86_64.whl size=156583 sha256=3bb572293a89edbc5dee44470548c19d6a61a65b2b5c460a3f2ba044bd6422df
#   Stored in directory: /root/.cache/pip/wheels/4d/51/5b/987888cacaf8bb25982ef4569261f68debe85b7587c5563c79
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.6

# %%
import numpy as np
import os
import time
import MeCab

import preprocess_utils
import model
import weight_utils

import tensorflow.keras as keras
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# # 日英翻訳データ ダウンロード

# %%
# !wget http://www.manythings.org/anki/jpn-eng.zip
# !unzip ./jpn-eng.zip
# Out:
# --2021-07-15 13:45:58--  http://www.manythings.org/anki/jpn-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 172.67.173.198, 104.21.55.222, 2606:4700:3036::ac43:adc6, ...
# Connecting to www.manythings.org (www.manythings.org)|172.67.173.198|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3251394 (3.1M) [application/zip]
# Saving to: ‘jpn-eng.zip.1’
#
# jpn-eng.zip.1       100%[===================>]   3.10M  3.27MB/s    in 0.9s
#
# 2021-07-15 13:46:00 (3.27 MB/s) - ‘jpn-eng.zip.1’ saved [3251394/3251394]
#
# Archive:  ./jpn-eng.zip
# replace jpn.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: jpn.txt
# replace _about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: _about.txt

# %% [markdown]
# # データ読み込み

# %%
dataset = preprocess_utils.CreateData(
    corpus_path = './jpn.txt',
    do_shuffle=True,
    seed_value=123,
    split_percent=0.95 # 学習データの割合
)

train_source, train_target, test_source, test_target, train_licence, test_licence = dataset.split_data()

print('**** Amount of data ****')
print('train_source： ', len(train_source))
print('train_target： ', len(train_target))
print('test_source： ', len(test_source))
print('test_target： ', len(test_target))
print('\n')
print('**** Train data example ****')
print('Source Example： ', train_source[0])
print('Target Example： ', train_target[0])
print('Licence： ', train_licence[0])
print('\n')
print('**** Test data example ****')
print('Source Example： ', test_source[0])
print('Target Example： ', test_target[0])
print('Licence： ', test_licence[0])
# Out:
# **** Amount of data ****
# train_source：  73925
# train_target：  73925
# test_source：  3891
# test_target：  3891
#
#
# **** Train data example ****
# Source Example：  This fish is big.
# Target Example：  この魚は大きいな。
# Licence：  CC-BY 2.0 (France) Attribution: tatoeba.org #59689 (CK) & #222362 (small_snow)
#
#
#
# **** Test data example ****
# Source Example：  Why did you want to buy that?
# Target Example：  なんでそれを買いたかったの？
# Licence：  CC-BY 2.0 (France) Attribution: tatoeba.org #7989199 (CK) & #7989408 (Ninja)

# %% [markdown]
# # 前処理

# %%
BATCH_SIZE = 64 # バッチサイズ
MAX_LENGTH = 60 # シーケンスの長さ
USE_TPU = False # TPUを使うか
BUFFER_SIZE = 50000

# %%
train_dataset = preprocess_utils.PreprocessData(
    mecab = MeCab.Tagger("-Ochasen"),
    source_data = train_source,
    target_data = train_target,
    max_length = MAX_LENGTH,
    batch_size = BATCH_SIZE,
    test_flag = False,
    train_dataset = None,
)

train_dataset.preprocess_data()

# %%
if USE_TPU:
  tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
  tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
  tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)    
  strategy = tf.distribute.experimental.TPUStrategy(tpu_cluster_resolver)

trainset = tf.data.Dataset.from_tensor_slices((train_dataset.source_vector, train_dataset.target_vector))
trainset = trainset.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))).shuffle(buffer_size=BUFFER_SIZE).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

if USE_TPU:
  trainset = strategy.experimental_distribute_dataset(trainset)

# %% [markdown]
# # モデル定義

# %%
num_layers=4 # レイヤー数
d_model=64 # 中間層の次元数
num_heads=4 # Multi Head Attentionのヘッド数
dff=2048 # Feed Forward Networkの次元数
dropout_rate = 0.1 # ドロップアウト率

source_vocab_size = max(train_dataset.source_token.values()) + 1 # source文の語彙数
target_vocab_size = max(train_dataset.target_token.values()) + 1 # target文の語彙数

# %%
# 重み初期化
def initialize_weight(checkpoint_path, optimizer, transformer, max_length, batch_size, use_tpu=False):

  if os.path.exists(checkpoint_path+'.pkl'):
    if use_tpu:
      number_of_tpu_cores = tpu_cluster_resolver.num_accelerators()['TPU']
      initialize_source, initialize_target = [[1]*max_length]*number_of_tpu_cores, [[1]*max_length]*number_of_tpu_cores
      initialize_set = tf.data.Dataset.from_tensor_slices((initialize_source, initialize_target))
      initialize_set = initialize_set.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))
          ).shuffle(buffer_size=BUFFER_SIZE).batch(batch_size).prefetch(
              buffer_size=tf.data.experimental.AUTOTUNE
          )
      initialize_set = strategy.experimental_distribute_dataset(initialize_set)

      for inp, tar in initialize_set:
        distributed_train_step(inp, tar)

    else:
      initialize_set = tf.ones([batch_size, max_length], tf.int64)
      train_step(initialize_set, initialize_set)
    
    try:
      weight_utils.load_weights_from_pickle(checkpoint_path, optimizer, transformer)
    except:
      print('Failed to load checkpoints.')

  else:
    print('No available checkpoints.')

# %% [markdown]
# # 学習実行

# %%
# Transformer
transformer = model.Transformer(num_layers, d_model, num_heads, dff,
                          source_vocab_size, target_vocab_size, 
                          pe_input=source_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# Learning Rate
learning_rate = model.CustomSchedule(d_model)

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# Loss
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# Loss Function
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  return tf.reduce_mean(loss_)

# Metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# Checkpoint
checkpoint_path = "/content/drive/My Drive/Transformer-master/checkpoints/gpu/model"

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]
@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  enc_padding_mask, combined_mask, dec_padding_mask = model.create_masks(inp, tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp, 
                                 True, 
                                 enc_padding_mask, 
                                 combined_mask, 
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(tar_real, predictions)

# Initialize Weight
initialize_weight(checkpoint_path, optimizer, transformer, MAX_LENGTH, BATCH_SIZE, use_tpu=USE_TPU)

EPOCHS = 30
batch = 0

for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  for inp, tar in trainset:
    train_step(inp, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
    batch+=1
      
  if (epoch + 1) % 5 == 0:
    print('Saving checkpoint for epoch {} at {}'.format(epoch+1, checkpoint_path))
    weight_utils.save_weights_as_pickle(checkpoint_path, optimizer, transformer)
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Load checkpoints successfully.
# Epoch 1 Batch 0 Loss 0.3481 Accuracy 0.1094
# Epoch 1 Batch 50 Loss 0.3569 Accuracy 0.1101
# Epoch 1 Batch 100 Loss 0.3555 Accuracy 0.1109
# Epoch 1 Batch 150 Loss 0.3514 Accuracy 0.1115
# Epoch 1 Batch 200 Loss 0.3494 Accuracy 0.1122
# Epoch 1 Batch 250 Loss 0.3466 Accuracy 0.1125
# Epoch 1 Batch 300 Loss 0.3439 Accuracy 0.1130
# Epoch 1 Batch 350 Loss 0.3426 Accuracy 0.1134
# Epoch 1 Batch 400 Loss 0.3418 Accuracy 0.1134
# Epoch 1 Batch 450 Loss 0.3410 Accuracy 0.1137
# Epoch 1 Batch 500 Loss 0.3391 Accuracy 0.1138
# Epoch 1 Batch 550 Loss 0.3372 Accuracy 0.1139
# Epoch 1 Batch 600 Loss 0.3366 Accuracy 0.1142
# Epoch 1 Batch 650 Loss 0.3356 Accuracy 0.1143
# Epoch 1 Batch 700 Loss 0.3355 Accuracy 0.1144
# Epoch 1 Batch 750 Loss 0.3345 Accuracy 0.1145
# Epoch 1 Batch 800 Loss 0.3342 Accuracy 0.1147
# Epoch 1 Batch 850 Loss 0.3336 Accuracy 0.1147
# Epoch 1 Batch 900 Loss 0.3331 Accuracy 0.1147
# Epoch 1 Batch 950 Loss 0.3329 Accuracy 0.1148
# Epoch 1 Batch 1000 Loss 0.3329 Accuracy 0.1149
# Epoch 1 Batch 1050 Loss 0.3331 Accuracy 0.1149
# Epoch 1 Batch 1100 Loss 0.3329 Accuracy 0.1150
# Epoch 1 Batch 1150 Loss 0.3327 Accuracy 0.1151
# Epoch 1 Loss 0.3324 Accuracy 0.1150
# Time taken for 1 epoch: 242.63260674476624 secs
#
# Epoch 2 Batch 1200 Loss 0.3156 Accuracy 0.1173
# Epoch 2 Batch 1250 Loss 0.3156 Accuracy 0.1170
# Epoch 2 Batch 1300 Loss 0.3196 Accuracy 0.1163
# Epoch 2 Batch 1350 Loss 0.3214 Accuracy 0.1164
# Epoch 2 Batch 1400 Loss 0.3220 Accuracy 0.1163
# Epoch 2 Batch 1450 Loss 0.3219 Accuracy 0.1165
# Epoch 2 Batch 1500 Loss 0.3227 Accuracy 0.1166
# Epoch 2 Batch 1550 Loss 0.3236 Accuracy 0.1164
# Epoch 2 Batch 1600 Loss 0.3241 Accuracy 0.1165
# Epoch 2 Batch 1650 Loss 0.3243 Accuracy 0.1165
# Epoch 2 Batch 1700 Loss 0.3253 Accuracy 0.1166
# Epoch 2 Batch 1750 Loss 0.3250 Accuracy 0.1166
# Epoch 2 Batch 1800 Loss 0.3254 Accuracy 0.1165
# Epoch 2 Batch 1850 Loss 0.3258 Accuracy 0.1164
# Epoch 2 Batch 1900 Loss 0.3262 Accuracy 0.1164
# Epoch 2 Batch 1950 Loss 0.3270 Accuracy 0.1163
# Epoch 2 Batch 2000 Loss 0.3271 Accuracy 0.1162
# Epoch 2 Batch 2050 Loss 0.3276 Accuracy 0.1161
# Epoch 2 Batch 2100 Loss 0.3279 Accuracy 0.1161
# Epoch 2 Batch 2150 Loss 0.3286 Accuracy 0.1161
# Epoch 2 Batch 2200 Loss 0.3289 Accuracy 0.1160
# Epoch 2 Batch 2250 Loss 0.3296 Accuracy 0.1160
# Epoch 2 Batch 2300 Loss 0.3301 Accuracy 0.1160
# Epoch 2 Loss 0.3303 Accuracy 0.1160
# Time taken for 1 epoch: 240.10891819000244 secs
#
# Epoch 3 Batch 2350 Loss 0.3173 Accuracy 0.1169
# Epoch 3 Batch 2400 Loss 0.3183 Accuracy 0.1167
# Epoch 3 Batch 2450 Loss 0.3182 Accuracy 0.1170
# Epoch 3 Batch 2500 Loss 0.3204 Accuracy 0.1170
# Epoch 3 Batch 2550 Loss 0.3211 Accuracy 0.1169
# Epoch 3 Batch 2600 Loss 0.3213 Accuracy 0.1169
# Epoch 3 Batch 2650 Loss 0.3217 Accuracy 0.1168
# Epoch 3 Batch 2700 Loss 0.3222 Accuracy 0.1166
# Epoch 3 Batch 2750 Loss 0.3242 Accuracy 0.1166
# Epoch 3 Batch 2800 Loss 0.3247 Accuracy 0.1164
# Epoch 3 Batch 2850 Loss 0.3266 Accuracy 0.1161
# Epoch 3 Batch 2900 Loss 0.3280 Accuracy 0.1160
# Epoch 3 Batch 2950 Loss 0.3289 Accuracy 0.1160
# Epoch 3 Batch 3000 Loss 0.3301 Accuracy 0.1159
# Epoch 3 Batch 3050 Loss 0.3302 Accuracy 0.1157
# Epoch 3 Batch 3100 Loss 0.3306 Accuracy 0.1156
# Epoch 3 Batch 3150 Loss 0.3314 Accuracy 0.1155
# Epoch 3 Batch 3200 Loss 0.3321 Accuracy 0.1154
# Epoch 3 Batch 3250 Loss 0.3326 Accuracy 0.1153
# Epoch 3 Batch 3300 Loss 0.3337 Accuracy 0.1152
# Epoch 3 Batch 3350 Loss 0.3342 Accuracy 0.1151
# Epoch 3 Batch 3400 Loss 0.3348 Accuracy 0.1150
# Epoch 3 Batch 3450 Loss 0.3355 Accuracy 0.1149
# Epoch 3 Loss 0.3356 Accuracy 0.1149
# Time taken for 1 epoch: 239.91246557235718 secs
#
# Epoch 4 Batch 3500 Loss 0.3159 Accuracy 0.1156
# Epoch 4 Batch 3550 Loss 0.3170 Accuracy 0.1156
# Epoch 4 Batch 3600 Loss 0.3222 Accuracy 0.1158
# Epoch 4 Batch 3650 Loss 0.3237 Accuracy 0.1155
# Epoch 4 Batch 3700 Loss 0.3236 Accuracy 0.1153
# Epoch 4 Batch 3750 Loss 0.3247 Accuracy 0.1152
# Epoch 4 Batch 3800 Loss 0.3266 Accuracy 0.1150
# Epoch 4 Batch 3850 Loss 0.3284 Accuracy 0.1149
# Epoch 4 Batch 3900 Loss 0.3288 Accuracy 0.1149
# Epoch 4 Batch 3950 Loss 0.3304 Accuracy 0.1148
# Epoch 4 Batch 4000 Loss 0.3318 Accuracy 0.1148
# Epoch 4 Batch 4050 Loss 0.3334 Accuracy 0.1147
# Epoch 4 Batch 4100 Loss 0.3342 Accuracy 0.1146
# Epoch 4 Batch 4150 Loss 0.3344 Accuracy 0.1145
# Epoch 4 Batch 4200 Loss 0.3351 Accuracy 0.1144
# Epoch 4 Batch 4250 Loss 0.3360 Accuracy 0.1143
# Epoch 4 Batch 4300 Loss 0.3369 Accuracy 0.1143
# Epoch 4 Batch 4350 Loss 0.3369 Accuracy 0.1142
# Epoch 4 Batch 4400 Loss 0.3376 Accuracy 0.1141
# Epoch 4 Batch 4450 Loss 0.3379 Accuracy 0.1141
# Epoch 4 Batch 4500 Loss 0.3381 Accuracy 0.1141
# Epoch 4 Batch 4550 Loss 0.3386 Accuracy 0.1141
# Epoch 4 Batch 4600 Loss 0.3389 Accuracy 0.1141
# Epoch 4 Loss 0.3391 Accuracy 0.1141
# Time taken for 1 epoch: 240.86107277870178 secs
#
# Epoch 5 Batch 4650 Loss 0.3117 Accuracy 0.1174
# Epoch 5 Batch 4700 Loss 0.3154 Accuracy 0.1167
# Epoch 5 Batch 4750 Loss 0.3146 Accuracy 0.1161
# Epoch 5 Batch 4800 Loss 0.3152 Accuracy 0.1161
# Epoch 5 Batch 4850 Loss 0.3170 Accuracy 0.1162
# Epoch 5 Batch 4900 Loss 0.3162 Accuracy 0.1161
# Epoch 5 Batch 4950 Loss 0.3185 Accuracy 0.1162
# Epoch 5 Batch 5000 Loss 0.3200 Accuracy 0.1163
# Epoch 5 Batch 5050 Loss 0.3199 Accuracy 0.1163
# Epoch 5 Batch 5100 Loss 0.3205 Accuracy 0.1165
# Epoch 5 Batch 5150 Loss 0.3206 Accuracy 0.1165
# Epoch 5 Batch 5200 Loss 0.3214 Accuracy 0.1165
# Epoch 5 Batch 5250 Loss 0.3213 Accuracy 0.1165
# Epoch 5 Batch 5300 Loss 0.3216 Accuracy 0.1166
# Epoch 5 Batch 5350 Loss 0.3220 Accuracy 0.1166
# Epoch 5 Batch 5400 Loss 0.3222 Accuracy 0.1166
# Epoch 5 Batch 5450 Loss 0.3229 Accuracy 0.1165
# Epoch 5 Batch 5500 Loss 0.3230 Accuracy 0.1165
# Epoch 5 Batch 5550 Loss 0.3235 Accuracy 0.1165
# Epoch 5 Batch 5600 Loss 0.3238 Accuracy 0.1165
# Epoch 5 Batch 5650 Loss 0.3239 Accuracy 0.1165
# Epoch 5 Batch 5700 Loss 0.3244 Accuracy 0.1165
# Epoch 5 Batch 5750 Loss 0.3247 Accuracy 0.1165
# Saving checkpoint for epoch 5 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 5 Loss 0.3251 Accuracy 0.1165
# Time taken for 1 epoch: 239.68386363983154 secs
#
# Epoch 6 Batch 5800 Loss 0.2958 Accuracy 0.1178
# Epoch 6 Batch 5850 Loss 0.2926 Accuracy 0.1193
# Epoch 6 Batch 5900 Loss 0.2955 Accuracy 0.1194
# Epoch 6 Batch 5950 Loss 0.3002 Accuracy 0.1191
# Epoch 6 Batch 6000 Loss 0.3000 Accuracy 0.1191
# Epoch 6 Batch 6050 Loss 0.3013 Accuracy 0.1191
# Epoch 6 Batch 6100 Loss 0.3016 Accuracy 0.1191
# Epoch 6 Batch 6150 Loss 0.3030 Accuracy 0.1192
# Epoch 6 Batch 6200 Loss 0.3039 Accuracy 0.1192
# Epoch 6 Batch 6250 Loss 0.3047 Accuracy 0.1192
# Epoch 6 Batch 6300 Loss 0.3047 Accuracy 0.1193
# Epoch 6 Batch 6350 Loss 0.3049 Accuracy 0.1192
# Epoch 6 Batch 6400 Loss 0.3057 Accuracy 0.1192
# Epoch 6 Batch 6450 Loss 0.3066 Accuracy 0.1192
# Epoch 6 Batch 6500 Loss 0.3070 Accuracy 0.1192
# Epoch 6 Batch 6550 Loss 0.3072 Accuracy 0.1191
# Epoch 6 Batch 6600 Loss 0.3077 Accuracy 0.1190
# Epoch 6 Batch 6650 Loss 0.3083 Accuracy 0.1190
# Epoch 6 Batch 6700 Loss 0.3082 Accuracy 0.1190
# Epoch 6 Batch 6750 Loss 0.3084 Accuracy 0.1190
# Epoch 6 Batch 6800 Loss 0.3090 Accuracy 0.1191
# Epoch 6 Batch 6850 Loss 0.3094 Accuracy 0.1190
# Epoch 6 Batch 6900 Loss 0.3099 Accuracy 0.1190
# Epoch 6 Loss 0.3099 Accuracy 0.1190
# Time taken for 1 epoch: 240.34396934509277 secs
#
# Epoch 7 Batch 6950 Loss 0.2787 Accuracy 0.1181
# Epoch 7 Batch 7000 Loss 0.2814 Accuracy 0.1216
# Epoch 7 Batch 7050 Loss 0.2834 Accuracy 0.1215
# Epoch 7 Batch 7100 Loss 0.2851 Accuracy 0.1216
# Epoch 7 Batch 7150 Loss 0.2842 Accuracy 0.1211
# Epoch 7 Batch 7200 Loss 0.2857 Accuracy 0.1210
# Epoch 7 Batch 7250 Loss 0.2879 Accuracy 0.1211
# Epoch 7 Batch 7300 Loss 0.2881 Accuracy 0.1213
# Epoch 7 Batch 7350 Loss 0.2890 Accuracy 0.1213
# Epoch 7 Batch 7400 Loss 0.2899 Accuracy 0.1214
# Epoch 7 Batch 7450 Loss 0.2902 Accuracy 0.1215
# Epoch 7 Batch 7500 Loss 0.2912 Accuracy 0.1214
# Epoch 7 Batch 7550 Loss 0.2921 Accuracy 0.1213
# Epoch 7 Batch 7600 Loss 0.2928 Accuracy 0.1212
# Epoch 7 Batch 7650 Loss 0.2938 Accuracy 0.1212
# Epoch 7 Batch 7700 Loss 0.2944 Accuracy 0.1211
# Epoch 7 Batch 7750 Loss 0.2951 Accuracy 0.1210
# Epoch 7 Batch 7800 Loss 0.2957 Accuracy 0.1210
# Epoch 7 Batch 7850 Loss 0.2961 Accuracy 0.1209
# Epoch 7 Batch 7900 Loss 0.2967 Accuracy 0.1209
# Epoch 7 Batch 7950 Loss 0.2976 Accuracy 0.1209
# Epoch 7 Batch 8000 Loss 0.2978 Accuracy 0.1209
# Epoch 7 Batch 8050 Loss 0.2984 Accuracy 0.1209
# Epoch 7 Loss 0.2985 Accuracy 0.1209
# Time taken for 1 epoch: 239.80645370483398 secs
#
# Epoch 8 Batch 8100 Loss 0.2790 Accuracy 0.1212
# Epoch 8 Batch 8150 Loss 0.2690 Accuracy 0.1227
# Epoch 8 Batch 8200 Loss 0.2741 Accuracy 0.1231
# Epoch 8 Batch 8250 Loss 0.2761 Accuracy 0.1232
# Epoch 8 Batch 8300 Loss 0.2775 Accuracy 0.1234
# Epoch 8 Batch 8350 Loss 0.2790 Accuracy 0.1233
# Epoch 8 Batch 8400 Loss 0.2787 Accuracy 0.1233
# Epoch 8 Batch 8450 Loss 0.2783 Accuracy 0.1233
# Epoch 8 Batch 8500 Loss 0.2794 Accuracy 0.1233
# Epoch 8 Batch 8550 Loss 0.2802 Accuracy 0.1233
# Epoch 8 Batch 8600 Loss 0.2813 Accuracy 0.1233
# Epoch 8 Batch 8650 Loss 0.2825 Accuracy 0.1232
# Epoch 8 Batch 8700 Loss 0.2825 Accuracy 0.1232
# Epoch 8 Batch 8750 Loss 0.2829 Accuracy 0.1231
# Epoch 8 Batch 8800 Loss 0.2840 Accuracy 0.1230
# Epoch 8 Batch 8850 Loss 0.2843 Accuracy 0.1229
# Epoch 8 Batch 8900 Loss 0.2853 Accuracy 0.1230
# Epoch 8 Batch 8950 Loss 0.2857 Accuracy 0.1228
# Epoch 8 Batch 9000 Loss 0.2861 Accuracy 0.1227
# Epoch 8 Batch 9050 Loss 0.2867 Accuracy 0.1227
# Epoch 8 Batch 9100 Loss 0.2872 Accuracy 0.1227
# Epoch 8 Batch 9150 Loss 0.2874 Accuracy 0.1226
# Epoch 8 Batch 9200 Loss 0.2879 Accuracy 0.1227
# Epoch 8 Loss 0.2885 Accuracy 0.1227
# Time taken for 1 epoch: 240.69835782051086 secs
#
# Epoch 9 Batch 9250 Loss 0.2596 Accuracy 0.1247
# Epoch 9 Batch 9300 Loss 0.2642 Accuracy 0.1254
# Epoch 9 Batch 9350 Loss 0.2633 Accuracy 0.1254
# Epoch 9 Batch 9400 Loss 0.2647 Accuracy 0.1252
# Epoch 9 Batch 9450 Loss 0.2665 Accuracy 0.1253
# Epoch 9 Batch 9500 Loss 0.2662 Accuracy 0.1252
# Epoch 9 Batch 9550 Loss 0.2674 Accuracy 0.1252
# Epoch 9 Batch 9600 Loss 0.2688 Accuracy 0.1252
# Epoch 9 Batch 9650 Loss 0.2704 Accuracy 0.1253
# Epoch 9 Batch 9700 Loss 0.2718 Accuracy 0.1251
# Epoch 9 Batch 9750 Loss 0.2726 Accuracy 0.1252
# Epoch 9 Batch 9800 Loss 0.2735 Accuracy 0.1249
# Epoch 9 Batch 9850 Loss 0.2739 Accuracy 0.1248
# Epoch 9 Batch 9900 Loss 0.2746 Accuracy 0.1247
# Epoch 9 Batch 9950 Loss 0.2751 Accuracy 0.1247
# Epoch 9 Batch 10000 Loss 0.2759 Accuracy 0.1246
# Epoch 9 Batch 10050 Loss 0.2762 Accuracy 0.1245
# Epoch 9 Batch 10100 Loss 0.2767 Accuracy 0.1244
# Epoch 9 Batch 10150 Loss 0.2777 Accuracy 0.1243
# Epoch 9 Batch 10200 Loss 0.2781 Accuracy 0.1243
# Epoch 9 Batch 10250 Loss 0.2789 Accuracy 0.1242
# Epoch 9 Batch 10300 Loss 0.2796 Accuracy 0.1242
# Epoch 9 Batch 10350 Loss 0.2801 Accuracy 0.1242
# Epoch 9 Batch 10400 Loss 0.2804 Accuracy 0.1241
# Epoch 9 Loss 0.2803 Accuracy 0.1241
# Time taken for 1 epoch: 241.0280315876007 secs
#
# Epoch 10 Batch 10450 Loss 0.2608 Accuracy 0.1261
# Epoch 10 Batch 10500 Loss 0.2612 Accuracy 0.1260
# Epoch 10 Batch 10550 Loss 0.2626 Accuracy 0.1259
# Epoch 10 Batch 10600 Loss 0.2622 Accuracy 0.1256
# Epoch 10 Batch 10650 Loss 0.2633 Accuracy 0.1253
# Epoch 10 Batch 10700 Loss 0.2637 Accuracy 0.1252
# Epoch 10 Batch 10750 Loss 0.2646 Accuracy 0.1252
# Epoch 10 Batch 10800 Loss 0.2637 Accuracy 0.1252
# Epoch 10 Batch 10850 Loss 0.2643 Accuracy 0.1254
# Epoch 10 Batch 10900 Loss 0.2651 Accuracy 0.1253
# Epoch 10 Batch 10950 Loss 0.2655 Accuracy 0.1253
# Epoch 10 Batch 11000 Loss 0.2666 Accuracy 0.1253
# Epoch 10 Batch 11050 Loss 0.2675 Accuracy 0.1254
# Epoch 10 Batch 11100 Loss 0.2680 Accuracy 0.1254
# Epoch 10 Batch 11150 Loss 0.2683 Accuracy 0.1253
# Epoch 10 Batch 11200 Loss 0.2688 Accuracy 0.1252
# Epoch 10 Batch 11250 Loss 0.2696 Accuracy 0.1252
# Epoch 10 Batch 11300 Loss 0.2703 Accuracy 0.1253
# Epoch 10 Batch 11350 Loss 0.2707 Accuracy 0.1253
# Epoch 10 Batch 11400 Loss 0.2720 Accuracy 0.1253
# Epoch 10 Batch 11450 Loss 0.2727 Accuracy 0.1253
# Epoch 10 Batch 11500 Loss 0.2733 Accuracy 0.1253
# Epoch 10 Batch 11550 Loss 0.2739 Accuracy 0.1253
# Saving checkpoint for epoch 10 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 10 Loss 0.2738 Accuracy 0.1253
# Time taken for 1 epoch: 240.62099266052246 secs
#
# Epoch 11 Batch 11600 Loss 0.2585 Accuracy 0.1274
# Epoch 11 Batch 11650 Loss 0.2548 Accuracy 0.1284
# Epoch 11 Batch 11700 Loss 0.2556 Accuracy 0.1285
# Epoch 11 Batch 11750 Loss 0.2544 Accuracy 0.1280
# Epoch 11 Batch 11800 Loss 0.2560 Accuracy 0.1280
# Epoch 11 Batch 11850 Loss 0.2569 Accuracy 0.1277
# Epoch 11 Batch 11900 Loss 0.2569 Accuracy 0.1275
# Epoch 11 Batch 11950 Loss 0.2573 Accuracy 0.1276
# Epoch 11 Batch 12000 Loss 0.2580 Accuracy 0.1274
# Epoch 11 Batch 12050 Loss 0.2591 Accuracy 0.1273
# Epoch 11 Batch 12100 Loss 0.2605 Accuracy 0.1272
# Epoch 11 Batch 12150 Loss 0.2606 Accuracy 0.1271
# Epoch 11 Batch 12200 Loss 0.2617 Accuracy 0.1269
# Epoch 11 Batch 12250 Loss 0.2623 Accuracy 0.1268
# Epoch 11 Batch 12300 Loss 0.2634 Accuracy 0.1267
# Epoch 11 Batch 12350 Loss 0.2640 Accuracy 0.1267
# Epoch 11 Batch 12400 Loss 0.2645 Accuracy 0.1267
# Epoch 11 Batch 12450 Loss 0.2650 Accuracy 0.1265
# Epoch 11 Batch 12500 Loss 0.2656 Accuracy 0.1265
# Epoch 11 Batch 12550 Loss 0.2661 Accuracy 0.1265
# Epoch 11 Batch 12600 Loss 0.2665 Accuracy 0.1265
# Epoch 11 Batch 12650 Loss 0.2670 Accuracy 0.1264
# Epoch 11 Batch 12700 Loss 0.2676 Accuracy 0.1264
# Epoch 11 Loss 0.2677 Accuracy 0.1264
# Time taken for 1 epoch: 241.47183895111084 secs
#
# Epoch 12 Batch 12750 Loss 0.2461 Accuracy 0.1287
# Epoch 12 Batch 12800 Loss 0.2469 Accuracy 0.1294
# Epoch 12 Batch 12850 Loss 0.2489 Accuracy 0.1293
# Epoch 12 Batch 12900 Loss 0.2504 Accuracy 0.1292
# Epoch 12 Batch 12950 Loss 0.2499 Accuracy 0.1288
# Epoch 12 Batch 13000 Loss 0.2514 Accuracy 0.1286
# Epoch 12 Batch 13050 Loss 0.2528 Accuracy 0.1286
# Epoch 12 Batch 13100 Loss 0.2539 Accuracy 0.1285
# Epoch 12 Batch 13150 Loss 0.2543 Accuracy 0.1283
# Epoch 12 Batch 13200 Loss 0.2553 Accuracy 0.1283
# Epoch 12 Batch 13250 Loss 0.2554 Accuracy 0.1282
# Epoch 12 Batch 13300 Loss 0.2558 Accuracy 0.1280
# Epoch 12 Batch 13350 Loss 0.2562 Accuracy 0.1278
# Epoch 12 Batch 13400 Loss 0.2573 Accuracy 0.1278
# Epoch 12 Batch 13450 Loss 0.2581 Accuracy 0.1277
# Epoch 12 Batch 13500 Loss 0.2585 Accuracy 0.1276
# Epoch 12 Batch 13550 Loss 0.2591 Accuracy 0.1275
# Epoch 12 Batch 13600 Loss 0.2598 Accuracy 0.1275
# Epoch 12 Batch 13650 Loss 0.2601 Accuracy 0.1275
# Epoch 12 Batch 13700 Loss 0.2607 Accuracy 0.1275
# Epoch 12 Batch 13750 Loss 0.2613 Accuracy 0.1275
# Epoch 12 Batch 13800 Loss 0.2618 Accuracy 0.1275
# Epoch 12 Batch 13850 Loss 0.2620 Accuracy 0.1274
# Epoch 12 Loss 0.2623 Accuracy 0.1274
# Time taken for 1 epoch: 241.07089281082153 secs
#
# Epoch 13 Batch 13900 Loss 0.2415 Accuracy 0.1308
# Epoch 13 Batch 13950 Loss 0.2451 Accuracy 0.1300
# Epoch 13 Batch 14000 Loss 0.2442 Accuracy 0.1294
# Epoch 13 Batch 14050 Loss 0.2464 Accuracy 0.1292
# Epoch 13 Batch 14100 Loss 0.2466 Accuracy 0.1293
# Epoch 13 Batch 14150 Loss 0.2469 Accuracy 0.1291
# Epoch 13 Batch 14200 Loss 0.2481 Accuracy 0.1290
# Epoch 13 Batch 14250 Loss 0.2499 Accuracy 0.1291
# Epoch 13 Batch 14300 Loss 0.2501 Accuracy 0.1291
# Epoch 13 Batch 14350 Loss 0.2505 Accuracy 0.1291
# Epoch 13 Batch 14400 Loss 0.2501 Accuracy 0.1291
# Epoch 13 Batch 14450 Loss 0.2516 Accuracy 0.1290
# Epoch 13 Batch 14500 Loss 0.2524 Accuracy 0.1288
# Epoch 13 Batch 14550 Loss 0.2529 Accuracy 0.1288
# Epoch 13 Batch 14600 Loss 0.2533 Accuracy 0.1287
# Epoch 13 Batch 14650 Loss 0.2539 Accuracy 0.1286
# Epoch 13 Batch 14700 Loss 0.2546 Accuracy 0.1286
# Epoch 13 Batch 14750 Loss 0.2552 Accuracy 0.1285
# Epoch 13 Batch 14800 Loss 0.2558 Accuracy 0.1284
# Epoch 13 Batch 14850 Loss 0.2563 Accuracy 0.1284
# Epoch 13 Batch 14900 Loss 0.2567 Accuracy 0.1283
# Epoch 13 Batch 14950 Loss 0.2574 Accuracy 0.1283
# Epoch 13 Batch 15000 Loss 0.2577 Accuracy 0.1282
# Epoch 13 Loss 0.2577 Accuracy 0.1282
# Time taken for 1 epoch: 241.91377758979797 secs
#
# Epoch 14 Batch 15050 Loss 0.2331 Accuracy 0.1313
# Epoch 14 Batch 15100 Loss 0.2353 Accuracy 0.1306
# Epoch 14 Batch 15150 Loss 0.2381 Accuracy 0.1303
# Epoch 14 Batch 15200 Loss 0.2400 Accuracy 0.1300
# Epoch 14 Batch 15250 Loss 0.2414 Accuracy 0.1301
# Epoch 14 Batch 15300 Loss 0.2418 Accuracy 0.1298
# Epoch 14 Batch 15350 Loss 0.2425 Accuracy 0.1301
# Epoch 14 Batch 15400 Loss 0.2433 Accuracy 0.1301
# Epoch 14 Batch 15450 Loss 0.2441 Accuracy 0.1299
# Epoch 14 Batch 15500 Loss 0.2451 Accuracy 0.1298
# Epoch 14 Batch 15550 Loss 0.2460 Accuracy 0.1297
# Epoch 14 Batch 15600 Loss 0.2464 Accuracy 0.1296
# Epoch 14 Batch 15650 Loss 0.2471 Accuracy 0.1296
# Epoch 14 Batch 15700 Loss 0.2477 Accuracy 0.1295
# Epoch 14 Batch 15750 Loss 0.2485 Accuracy 0.1295
# Epoch 14 Batch 15800 Loss 0.2487 Accuracy 0.1295
# Epoch 14 Batch 15850 Loss 0.2497 Accuracy 0.1295
# Epoch 14 Batch 15900 Loss 0.2504 Accuracy 0.1294
# Epoch 14 Batch 15950 Loss 0.2510 Accuracy 0.1294
# Epoch 14 Batch 16000 Loss 0.2517 Accuracy 0.1293
# Epoch 14 Batch 16050 Loss 0.2518 Accuracy 0.1292
# Epoch 14 Batch 16100 Loss 0.2523 Accuracy 0.1292
# Epoch 14 Batch 16150 Loss 0.2527 Accuracy 0.1292
# Epoch 14 Loss 0.2532 Accuracy 0.1291
# Time taken for 1 epoch: 240.98446440696716 secs
#
# Epoch 15 Batch 16200 Loss 0.2236 Accuracy 0.1323
# Epoch 15 Batch 16250 Loss 0.2314 Accuracy 0.1304
# Epoch 15 Batch 16300 Loss 0.2356 Accuracy 0.1305
# Epoch 15 Batch 16350 Loss 0.2365 Accuracy 0.1304
# Epoch 15 Batch 16400 Loss 0.2382 Accuracy 0.1304
# Epoch 15 Batch 16450 Loss 0.2391 Accuracy 0.1305
# Epoch 15 Batch 16500 Loss 0.2396 Accuracy 0.1305
# Epoch 15 Batch 16550 Loss 0.2406 Accuracy 0.1306
# Epoch 15 Batch 16600 Loss 0.2409 Accuracy 0.1305
# Epoch 15 Batch 16650 Loss 0.2415 Accuracy 0.1305
# Epoch 15 Batch 16700 Loss 0.2420 Accuracy 0.1305
# Epoch 15 Batch 16750 Loss 0.2427 Accuracy 0.1303
# Epoch 15 Batch 16800 Loss 0.2432 Accuracy 0.1303
# Epoch 15 Batch 16850 Loss 0.2438 Accuracy 0.1302
# Epoch 15 Batch 16900 Loss 0.2446 Accuracy 0.1302
# Epoch 15 Batch 16950 Loss 0.2450 Accuracy 0.1301
# Epoch 15 Batch 17000 Loss 0.2461 Accuracy 0.1301
# Epoch 15 Batch 17050 Loss 0.2469 Accuracy 0.1301
# Epoch 15 Batch 17100 Loss 0.2478 Accuracy 0.1301
# Epoch 15 Batch 17150 Loss 0.2482 Accuracy 0.1301
# Epoch 15 Batch 17200 Loss 0.2484 Accuracy 0.1300
# Epoch 15 Batch 17250 Loss 0.2489 Accuracy 0.1299
# Epoch 15 Batch 17300 Loss 0.2492 Accuracy 0.1298
# Saving checkpoint for epoch 15 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 15 Loss 0.2496 Accuracy 0.1298
# Time taken for 1 epoch: 241.4274299144745 secs
#
# Epoch 16 Batch 17350 Loss 0.2171 Accuracy 0.1316
# Epoch 16 Batch 17400 Loss 0.2244 Accuracy 0.1315
# Epoch 16 Batch 17450 Loss 0.2264 Accuracy 0.1319
# Epoch 16 Batch 17500 Loss 0.2281 Accuracy 0.1315
# Epoch 16 Batch 17550 Loss 0.2299 Accuracy 0.1312
# Epoch 16 Batch 17600 Loss 0.2315 Accuracy 0.1311
# Epoch 16 Batch 17650 Loss 0.2331 Accuracy 0.1313
# Epoch 16 Batch 17700 Loss 0.2335 Accuracy 0.1311
# Epoch 16 Batch 17750 Loss 0.2349 Accuracy 0.1311
# Epoch 16 Batch 17800 Loss 0.2363 Accuracy 0.1312
# Epoch 16 Batch 17850 Loss 0.2376 Accuracy 0.1311
# Epoch 16 Batch 17900 Loss 0.2383 Accuracy 0.1311
# Epoch 16 Batch 17950 Loss 0.2387 Accuracy 0.1310
# Epoch 16 Batch 18000 Loss 0.2397 Accuracy 0.1309
# Epoch 16 Batch 18050 Loss 0.2401 Accuracy 0.1309
# Epoch 16 Batch 18100 Loss 0.2410 Accuracy 0.1309
# Epoch 16 Batch 18150 Loss 0.2419 Accuracy 0.1309
# Epoch 16 Batch 18200 Loss 0.2424 Accuracy 0.1310
# Epoch 16 Batch 18250 Loss 0.2432 Accuracy 0.1308
# Epoch 16 Batch 18300 Loss 0.2439 Accuracy 0.1308
# Epoch 16 Batch 18350 Loss 0.2444 Accuracy 0.1307
# Epoch 16 Batch 18400 Loss 0.2450 Accuracy 0.1306
# Epoch 16 Batch 18450 Loss 0.2456 Accuracy 0.1305
# Epoch 16 Loss 0.2462 Accuracy 0.1304
# Time taken for 1 epoch: 241.91297507286072 secs
#
# Epoch 17 Batch 18500 Loss 0.2306 Accuracy 0.1349
# Epoch 17 Batch 18550 Loss 0.2293 Accuracy 0.1325
# Epoch 17 Batch 18600 Loss 0.2283 Accuracy 0.1324
# Epoch 17 Batch 18650 Loss 0.2273 Accuracy 0.1322
# Epoch 17 Batch 18700 Loss 0.2283 Accuracy 0.1319
# Epoch 17 Batch 18750 Loss 0.2291 Accuracy 0.1320
# Epoch 17 Batch 18800 Loss 0.2309 Accuracy 0.1319
# Epoch 17 Batch 18850 Loss 0.2320 Accuracy 0.1317
# Epoch 17 Batch 18900 Loss 0.2328 Accuracy 0.1317
# Epoch 17 Batch 18950 Loss 0.2333 Accuracy 0.1316
# Epoch 17 Batch 19000 Loss 0.2342 Accuracy 0.1316
# Epoch 17 Batch 19050 Loss 0.2350 Accuracy 0.1315
# Epoch 17 Batch 19100 Loss 0.2356 Accuracy 0.1315
# Epoch 17 Batch 19150 Loss 0.2367 Accuracy 0.1315
# Epoch 17 Batch 19200 Loss 0.2376 Accuracy 0.1314
# Epoch 17 Batch 19250 Loss 0.2385 Accuracy 0.1315
# Epoch 17 Batch 19300 Loss 0.2392 Accuracy 0.1314
# Epoch 17 Batch 19350 Loss 0.2398 Accuracy 0.1314
# Epoch 17 Batch 19400 Loss 0.2398 Accuracy 0.1314
# Epoch 17 Batch 19450 Loss 0.2401 Accuracy 0.1313
# Epoch 17 Batch 19500 Loss 0.2409 Accuracy 0.1313
# Epoch 17 Batch 19550 Loss 0.2415 Accuracy 0.1312
# Epoch 17 Batch 19600 Loss 0.2422 Accuracy 0.1311
# Epoch 17 Batch 19650 Loss 0.2431 Accuracy 0.1311
# Epoch 17 Loss 0.2430 Accuracy 0.1311
# Time taken for 1 epoch: 241.31182265281677 secs
#
# Epoch 18 Batch 19700 Loss 0.2212 Accuracy 0.1337
# Epoch 18 Batch 19750 Loss 0.2239 Accuracy 0.1331
# Epoch 18 Batch 19800 Loss 0.2245 Accuracy 0.1326
# Epoch 18 Batch 19850 Loss 0.2250 Accuracy 0.1324
# Epoch 18 Batch 19900 Loss 0.2278 Accuracy 0.1321
# Epoch 18 Batch 19950 Loss 0.2282 Accuracy 0.1321
# Epoch 18 Batch 20000 Loss 0.2294 Accuracy 0.1320
# Epoch 18 Batch 20050 Loss 0.2302 Accuracy 0.1321
# Epoch 18 Batch 20100 Loss 0.2311 Accuracy 0.1321
# Epoch 18 Batch 20150 Loss 0.2324 Accuracy 0.1321
# Epoch 18 Batch 20200 Loss 0.2332 Accuracy 0.1320
# Epoch 18 Batch 20250 Loss 0.2340 Accuracy 0.1320
# Epoch 18 Batch 20300 Loss 0.2344 Accuracy 0.1319
# Epoch 18 Batch 20350 Loss 0.2350 Accuracy 0.1319
# Epoch 18 Batch 20400 Loss 0.2358 Accuracy 0.1319
# Epoch 18 Batch 20450 Loss 0.2363 Accuracy 0.1317
# Epoch 18 Batch 20500 Loss 0.2366 Accuracy 0.1317
# Epoch 18 Batch 20550 Loss 0.2370 Accuracy 0.1317
# Epoch 18 Batch 20600 Loss 0.2377 Accuracy 0.1317
# Epoch 18 Batch 20650 Loss 0.2384 Accuracy 0.1317
# Epoch 18 Batch 20700 Loss 0.2393 Accuracy 0.1317
# Epoch 18 Batch 20750 Loss 0.2397 Accuracy 0.1316
# Epoch 18 Batch 20800 Loss 0.2402 Accuracy 0.1316
# Epoch 18 Loss 0.2400 Accuracy 0.1316
# Time taken for 1 epoch: 242.24655938148499 secs
#
# Epoch 19 Batch 20850 Loss 0.2250 Accuracy 0.1331
# Epoch 19 Batch 20900 Loss 0.2222 Accuracy 0.1329
# Epoch 19 Batch 20950 Loss 0.2226 Accuracy 0.1325
# Epoch 19 Batch 21000 Loss 0.2252 Accuracy 0.1328
# Epoch 19 Batch 21050 Loss 0.2245 Accuracy 0.1331
# Epoch 19 Batch 21100 Loss 0.2258 Accuracy 0.1328
# Epoch 19 Batch 21150 Loss 0.2269 Accuracy 0.1328
# Epoch 19 Batch 21200 Loss 0.2278 Accuracy 0.1329
# Epoch 19 Batch 21250 Loss 0.2288 Accuracy 0.1330
# Epoch 19 Batch 21300 Loss 0.2298 Accuracy 0.1331
# Epoch 19 Batch 21350 Loss 0.2309 Accuracy 0.1330
# Epoch 19 Batch 21400 Loss 0.2315 Accuracy 0.1330
# Epoch 19 Batch 21450 Loss 0.2321 Accuracy 0.1330
# Epoch 19 Batch 21500 Loss 0.2329 Accuracy 0.1328
# Epoch 19 Batch 21550 Loss 0.2335 Accuracy 0.1327
# Epoch 19 Batch 21600 Loss 0.2339 Accuracy 0.1326
# Epoch 19 Batch 21650 Loss 0.2344 Accuracy 0.1326
# Epoch 19 Batch 21700 Loss 0.2346 Accuracy 0.1325
# Epoch 19 Batch 21750 Loss 0.2354 Accuracy 0.1324
# Epoch 19 Batch 21800 Loss 0.2360 Accuracy 0.1324
# Epoch 19 Batch 21850 Loss 0.2366 Accuracy 0.1324
# Epoch 19 Batch 21900 Loss 0.2369 Accuracy 0.1323
# Epoch 19 Batch 21950 Loss 0.2370 Accuracy 0.1323
# Epoch 19 Loss 0.2373 Accuracy 0.1322
# Time taken for 1 epoch: 241.48823976516724 secs
#
# Epoch 20 Batch 22000 Loss 0.2130 Accuracy 0.1342
# Epoch 20 Batch 22050 Loss 0.2171 Accuracy 0.1348
# Epoch 20 Batch 22100 Loss 0.2181 Accuracy 0.1348
# Epoch 20 Batch 22150 Loss 0.2192 Accuracy 0.1342
# Epoch 20 Batch 22200 Loss 0.2204 Accuracy 0.1341
# Epoch 20 Batch 22250 Loss 0.2218 Accuracy 0.1341
# Epoch 20 Batch 22300 Loss 0.2229 Accuracy 0.1340
# Epoch 20 Batch 22350 Loss 0.2246 Accuracy 0.1340
# Epoch 20 Batch 22400 Loss 0.2261 Accuracy 0.1341
# Epoch 20 Batch 22450 Loss 0.2270 Accuracy 0.1339
# Epoch 20 Batch 22500 Loss 0.2272 Accuracy 0.1336
# Epoch 20 Batch 22550 Loss 0.2274 Accuracy 0.1335
# Epoch 20 Batch 22600 Loss 0.2283 Accuracy 0.1335
# Epoch 20 Batch 22650 Loss 0.2288 Accuracy 0.1336
# Epoch 20 Batch 22700 Loss 0.2295 Accuracy 0.1336
# Epoch 20 Batch 22750 Loss 0.2299 Accuracy 0.1334
# Epoch 20 Batch 22800 Loss 0.2304 Accuracy 0.1333
# Epoch 20 Batch 22850 Loss 0.2309 Accuracy 0.1332
# Epoch 20 Batch 22900 Loss 0.2318 Accuracy 0.1331
# Epoch 20 Batch 22950 Loss 0.2322 Accuracy 0.1330
# Epoch 20 Batch 23000 Loss 0.2331 Accuracy 0.1329
# Epoch 20 Batch 23050 Loss 0.2340 Accuracy 0.1328
# Epoch 20 Batch 23100 Loss 0.2344 Accuracy 0.1328
# Saving checkpoint for epoch 20 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 20 Loss 0.2346 Accuracy 0.1328
# Time taken for 1 epoch: 242.11648535728455 secs
#
# Epoch 21 Batch 23150 Loss 0.2121 Accuracy 0.1354
# Epoch 21 Batch 23200 Loss 0.2131 Accuracy 0.1352
# Epoch 21 Batch 23250 Loss 0.2133 Accuracy 0.1347
# Epoch 21 Batch 23300 Loss 0.2174 Accuracy 0.1351
# Epoch 21 Batch 23350 Loss 0.2183 Accuracy 0.1350
# Epoch 21 Batch 23400 Loss 0.2190 Accuracy 0.1345
# Epoch 21 Batch 23450 Loss 0.2201 Accuracy 0.1343
# Epoch 21 Batch 23500 Loss 0.2215 Accuracy 0.1344
# Epoch 21 Batch 23550 Loss 0.2223 Accuracy 0.1343
# Epoch 21 Batch 23600 Loss 0.2230 Accuracy 0.1342
# Epoch 21 Batch 23650 Loss 0.2245 Accuracy 0.1342
# Epoch 21 Batch 23700 Loss 0.2255 Accuracy 0.1341
# Epoch 21 Batch 23750 Loss 0.2260 Accuracy 0.1340
# Epoch 21 Batch 23800 Loss 0.2269 Accuracy 0.1340
# Epoch 21 Batch 23850 Loss 0.2275 Accuracy 0.1338
# Epoch 21 Batch 23900 Loss 0.2279 Accuracy 0.1337
# Epoch 21 Batch 23950 Loss 0.2282 Accuracy 0.1337
# Epoch 21 Batch 24000 Loss 0.2289 Accuracy 0.1336
# Epoch 21 Batch 24050 Loss 0.2292 Accuracy 0.1335
# Epoch 21 Batch 24100 Loss 0.2300 Accuracy 0.1335
# Epoch 21 Batch 24150 Loss 0.2307 Accuracy 0.1334
# Epoch 21 Batch 24200 Loss 0.2313 Accuracy 0.1334
# Epoch 21 Batch 24250 Loss 0.2317 Accuracy 0.1333
# Epoch 21 Loss 0.2320 Accuracy 0.1333
# Time taken for 1 epoch: 241.420423746109 secs
#
# Epoch 22 Batch 24300 Loss 0.2127 Accuracy 0.1354
# Epoch 22 Batch 24350 Loss 0.2151 Accuracy 0.1356
# Epoch 22 Batch 24400 Loss 0.2166 Accuracy 0.1352
# Epoch 22 Batch 24450 Loss 0.2164 Accuracy 0.1352
# Epoch 22 Batch 24500 Loss 0.2184 Accuracy 0.1351
# Epoch 22 Batch 24550 Loss 0.2193 Accuracy 0.1350
# Epoch 22 Batch 24600 Loss 0.2199 Accuracy 0.1347
# Epoch 22 Batch 24650 Loss 0.2210 Accuracy 0.1347
# Epoch 22 Batch 24700 Loss 0.2218 Accuracy 0.1346
# Epoch 22 Batch 24750 Loss 0.2225 Accuracy 0.1344
# Epoch 22 Batch 24800 Loss 0.2229 Accuracy 0.1344
# Epoch 22 Batch 24850 Loss 0.2239 Accuracy 0.1342
# Epoch 22 Batch 24900 Loss 0.2245 Accuracy 0.1343
# Epoch 22 Batch 24950 Loss 0.2248 Accuracy 0.1342
# Epoch 22 Batch 25000 Loss 0.2257 Accuracy 0.1341
# Epoch 22 Batch 25050 Loss 0.2263 Accuracy 0.1340
# Epoch 22 Batch 25100 Loss 0.2264 Accuracy 0.1340
# Epoch 22 Batch 25150 Loss 0.2268 Accuracy 0.1339
# Epoch 22 Batch 25200 Loss 0.2273 Accuracy 0.1339
# Epoch 22 Batch 25250 Loss 0.2276 Accuracy 0.1338
# Epoch 22 Batch 25300 Loss 0.2281 Accuracy 0.1337
# Epoch 22 Batch 25350 Loss 0.2287 Accuracy 0.1337
# Epoch 22 Batch 25400 Loss 0.2292 Accuracy 0.1337
# Epoch 22 Loss 0.2295 Accuracy 0.1337
# Time taken for 1 epoch: 241.52838516235352 secs
#
# Epoch 23 Batch 25450 Loss 0.2101 Accuracy 0.1354
# Epoch 23 Batch 25500 Loss 0.2101 Accuracy 0.1361
# Epoch 23 Batch 25550 Loss 0.2107 Accuracy 0.1357
# Epoch 23 Batch 25600 Loss 0.2110 Accuracy 0.1355
# Epoch 23 Batch 25650 Loss 0.2126 Accuracy 0.1352
# Epoch 23 Batch 25700 Loss 0.2144 Accuracy 0.1352
# Epoch 23 Batch 25750 Loss 0.2160 Accuracy 0.1352
# Epoch 23 Batch 25800 Loss 0.2181 Accuracy 0.1351
# Epoch 23 Batch 25850 Loss 0.2190 Accuracy 0.1351
# Epoch 23 Batch 25900 Loss 0.2198 Accuracy 0.1350
# Epoch 23 Batch 25950 Loss 0.2202 Accuracy 0.1349
# Epoch 23 Batch 26000 Loss 0.2209 Accuracy 0.1347
# Epoch 23 Batch 26050 Loss 0.2216 Accuracy 0.1346
# Epoch 23 Batch 26100 Loss 0.2218 Accuracy 0.1346
# Epoch 23 Batch 26150 Loss 0.2227 Accuracy 0.1346
# Epoch 23 Batch 26200 Loss 0.2232 Accuracy 0.1346
# Epoch 23 Batch 26250 Loss 0.2233 Accuracy 0.1346
# Epoch 23 Batch 26300 Loss 0.2239 Accuracy 0.1344
# Epoch 23 Batch 26350 Loss 0.2245 Accuracy 0.1343
# Epoch 23 Batch 26400 Loss 0.2252 Accuracy 0.1342
# Epoch 23 Batch 26450 Loss 0.2258 Accuracy 0.1342
# Epoch 23 Batch 26500 Loss 0.2264 Accuracy 0.1342
# Epoch 23 Batch 26550 Loss 0.2272 Accuracy 0.1341
# Epoch 23 Loss 0.2273 Accuracy 0.1341
# Time taken for 1 epoch: 241.00498962402344 secs
#
# Epoch 24 Batch 26600 Loss 0.2245 Accuracy 0.1354
# Epoch 24 Batch 26650 Loss 0.2121 Accuracy 0.1355
# Epoch 24 Batch 26700 Loss 0.2137 Accuracy 0.1359
# Epoch 24 Batch 26750 Loss 0.2131 Accuracy 0.1355
# Epoch 24 Batch 26800 Loss 0.2131 Accuracy 0.1352
# Epoch 24 Batch 26850 Loss 0.2140 Accuracy 0.1353
# Epoch 24 Batch 26900 Loss 0.2132 Accuracy 0.1352
# Epoch 24 Batch 26950 Loss 0.2139 Accuracy 0.1351
# Epoch 24 Batch 27000 Loss 0.2152 Accuracy 0.1349
# Epoch 24 Batch 27050 Loss 0.2163 Accuracy 0.1348
# Epoch 24 Batch 27100 Loss 0.2174 Accuracy 0.1349
# Epoch 24 Batch 27150 Loss 0.2178 Accuracy 0.1349
# Epoch 24 Batch 27200 Loss 0.2189 Accuracy 0.1348
# Epoch 24 Batch 27250 Loss 0.2195 Accuracy 0.1347
# Epoch 24 Batch 27300 Loss 0.2198 Accuracy 0.1347
# Epoch 24 Batch 27350 Loss 0.2205 Accuracy 0.1346
# Epoch 24 Batch 27400 Loss 0.2209 Accuracy 0.1346
# Epoch 24 Batch 27450 Loss 0.2217 Accuracy 0.1345
# Epoch 24 Batch 27500 Loss 0.2226 Accuracy 0.1345
# Epoch 24 Batch 27550 Loss 0.2236 Accuracy 0.1345
# Epoch 24 Batch 27600 Loss 0.2244 Accuracy 0.1345
# Epoch 24 Batch 27650 Loss 0.2248 Accuracy 0.1344
# Epoch 24 Batch 27700 Loss 0.2253 Accuracy 0.1344
# Epoch 24 Loss 0.2256 Accuracy 0.1344
# Time taken for 1 epoch: 236.49692964553833 secs
#
# Epoch 25 Batch 27750 Loss 0.2310 Accuracy 0.1403
# Epoch 25 Batch 27800 Loss 0.2098 Accuracy 0.1357
# Epoch 25 Batch 27850 Loss 0.2100 Accuracy 0.1363
# Epoch 25 Batch 27900 Loss 0.2118 Accuracy 0.1362
# Epoch 25 Batch 27950 Loss 0.2128 Accuracy 0.1360
# Epoch 25 Batch 28000 Loss 0.2116 Accuracy 0.1359
# Epoch 25 Batch 28050 Loss 0.2122 Accuracy 0.1359
# Epoch 25 Batch 28100 Loss 0.2132 Accuracy 0.1358
# Epoch 25 Batch 28150 Loss 0.2145 Accuracy 0.1358
# Epoch 25 Batch 28200 Loss 0.2147 Accuracy 0.1357
# Epoch 25 Batch 28250 Loss 0.2155 Accuracy 0.1356
# Epoch 25 Batch 28300 Loss 0.2162 Accuracy 0.1356
# Epoch 25 Batch 28350 Loss 0.2168 Accuracy 0.1354
# Epoch 25 Batch 28400 Loss 0.2175 Accuracy 0.1353
# Epoch 25 Batch 28450 Loss 0.2184 Accuracy 0.1353
# Epoch 25 Batch 28500 Loss 0.2192 Accuracy 0.1353
# Epoch 25 Batch 28550 Loss 0.2200 Accuracy 0.1353
# Epoch 25 Batch 28600 Loss 0.2201 Accuracy 0.1352
# Epoch 25 Batch 28650 Loss 0.2208 Accuracy 0.1351
# Epoch 25 Batch 28700 Loss 0.2216 Accuracy 0.1351
# Epoch 25 Batch 28750 Loss 0.2222 Accuracy 0.1351
# Epoch 25 Batch 28800 Loss 0.2230 Accuracy 0.1350
# Epoch 25 Batch 28850 Loss 0.2236 Accuracy 0.1349
# Saving checkpoint for epoch 25 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 25 Loss 0.2239 Accuracy 0.1348
# Time taken for 1 epoch: 236.45626020431519 secs
#
# Epoch 26 Batch 28900 Loss 0.2173 Accuracy 0.1398
# Epoch 26 Batch 28950 Loss 0.2060 Accuracy 0.1363
# Epoch 26 Batch 29000 Loss 0.2063 Accuracy 0.1362
# Epoch 26 Batch 29050 Loss 0.2075 Accuracy 0.1363
# Epoch 26 Batch 29100 Loss 0.2087 Accuracy 0.1362
# Epoch 26 Batch 29150 Loss 0.2096 Accuracy 0.1361
# Epoch 26 Batch 29200 Loss 0.2108 Accuracy 0.1363
# Epoch 26 Batch 29250 Loss 0.2116 Accuracy 0.1362
# Epoch 26 Batch 29300 Loss 0.2120 Accuracy 0.1360
# Epoch 26 Batch 29350 Loss 0.2127 Accuracy 0.1360
# Epoch 26 Batch 29400 Loss 0.2131 Accuracy 0.1359
# Epoch 26 Batch 29450 Loss 0.2141 Accuracy 0.1359
# Epoch 26 Batch 29500 Loss 0.2150 Accuracy 0.1358
# Epoch 26 Batch 29550 Loss 0.2154 Accuracy 0.1357
# Epoch 26 Batch 29600 Loss 0.2161 Accuracy 0.1355
# Epoch 26 Batch 29650 Loss 0.2168 Accuracy 0.1356
# Epoch 26 Batch 29700 Loss 0.2174 Accuracy 0.1355
# Epoch 26 Batch 29750 Loss 0.2182 Accuracy 0.1355
# Epoch 26 Batch 29800 Loss 0.2188 Accuracy 0.1354
# Epoch 26 Batch 29850 Loss 0.2194 Accuracy 0.1355
# Epoch 26 Batch 29900 Loss 0.2201 Accuracy 0.1354
# Epoch 26 Batch 29950 Loss 0.2207 Accuracy 0.1354
# Epoch 26 Batch 30000 Loss 0.2212 Accuracy 0.1353
# Epoch 26 Batch 30050 Loss 0.2215 Accuracy 0.1353
# Epoch 26 Loss 0.2216 Accuracy 0.1353
# Time taken for 1 epoch: 235.98399138450623 secs
#
# Epoch 27 Batch 30100 Loss 0.2069 Accuracy 0.1362
# Epoch 27 Batch 30150 Loss 0.2036 Accuracy 0.1365
# Epoch 27 Batch 30200 Loss 0.2049 Accuracy 0.1367
# Epoch 27 Batch 30250 Loss 0.2051 Accuracy 0.1364
# Epoch 27 Batch 30300 Loss 0.2065 Accuracy 0.1365
# Epoch 27 Batch 30350 Loss 0.2084 Accuracy 0.1364
# Epoch 27 Batch 30400 Loss 0.2101 Accuracy 0.1365
# Epoch 27 Batch 30450 Loss 0.2108 Accuracy 0.1364
# Epoch 27 Batch 30500 Loss 0.2113 Accuracy 0.1363
# Epoch 27 Batch 30550 Loss 0.2125 Accuracy 0.1361
# Epoch 27 Batch 30600 Loss 0.2130 Accuracy 0.1361
# Epoch 27 Batch 30650 Loss 0.2138 Accuracy 0.1361
# Epoch 27 Batch 30700 Loss 0.2142 Accuracy 0.1360
# Epoch 27 Batch 30750 Loss 0.2149 Accuracy 0.1360
# Epoch 27 Batch 30800 Loss 0.2157 Accuracy 0.1359
# Epoch 27 Batch 30850 Loss 0.2162 Accuracy 0.1359
# Epoch 27 Batch 30900 Loss 0.2170 Accuracy 0.1358
# Epoch 27 Batch 30950 Loss 0.2177 Accuracy 0.1358
# Epoch 27 Batch 31000 Loss 0.2181 Accuracy 0.1357
# Epoch 27 Batch 31050 Loss 0.2185 Accuracy 0.1357
# Epoch 27 Batch 31100 Loss 0.2192 Accuracy 0.1357
# Epoch 27 Batch 31150 Loss 0.2197 Accuracy 0.1356
# Epoch 27 Batch 31200 Loss 0.2202 Accuracy 0.1356
# Epoch 27 Loss 0.2203 Accuracy 0.1356
# Time taken for 1 epoch: 235.77689695358276 secs
#
# Epoch 28 Batch 31250 Loss 0.1976 Accuracy 0.1379
# Epoch 28 Batch 31300 Loss 0.2040 Accuracy 0.1384
# Epoch 28 Batch 31350 Loss 0.2057 Accuracy 0.1377
# Epoch 28 Batch 31400 Loss 0.2063 Accuracy 0.1374
# Epoch 28 Batch 31450 Loss 0.2074 Accuracy 0.1375
# Epoch 28 Batch 31500 Loss 0.2082 Accuracy 0.1374
# Epoch 28 Batch 31550 Loss 0.2083 Accuracy 0.1371
# Epoch 28 Batch 31600 Loss 0.2092 Accuracy 0.1372
# Epoch 28 Batch 31650 Loss 0.2094 Accuracy 0.1372
# Epoch 28 Batch 31700 Loss 0.2105 Accuracy 0.1371
# Epoch 28 Batch 31750 Loss 0.2113 Accuracy 0.1371
# Epoch 28 Batch 31800 Loss 0.2121 Accuracy 0.1369
# Epoch 28 Batch 31850 Loss 0.2128 Accuracy 0.1369
# Epoch 28 Batch 31900 Loss 0.2135 Accuracy 0.1368
# Epoch 28 Batch 31950 Loss 0.2144 Accuracy 0.1368
# Epoch 28 Batch 32000 Loss 0.2147 Accuracy 0.1367
# Epoch 28 Batch 32050 Loss 0.2152 Accuracy 0.1365
# Epoch 28 Batch 32100 Loss 0.2154 Accuracy 0.1364
# Epoch 28 Batch 32150 Loss 0.2158 Accuracy 0.1363
# Epoch 28 Batch 32200 Loss 0.2165 Accuracy 0.1362
# Epoch 28 Batch 32250 Loss 0.2172 Accuracy 0.1362
# Epoch 28 Batch 32300 Loss 0.2176 Accuracy 0.1361
# Epoch 28 Batch 32350 Loss 0.2180 Accuracy 0.1360
# Epoch 28 Loss 0.2184 Accuracy 0.1360
# Time taken for 1 epoch: 235.7089433670044 secs
#
# Epoch 29 Batch 32400 Loss 0.1994 Accuracy 0.1379
# Epoch 29 Batch 32450 Loss 0.1982 Accuracy 0.1376
# Epoch 29 Batch 32500 Loss 0.1972 Accuracy 0.1378
# Epoch 29 Batch 32550 Loss 0.1996 Accuracy 0.1374
# Epoch 29 Batch 32600 Loss 0.2002 Accuracy 0.1375
# Epoch 29 Batch 32650 Loss 0.2015 Accuracy 0.1374
# Epoch 29 Batch 32700 Loss 0.2038 Accuracy 0.1373
# Epoch 29 Batch 32750 Loss 0.2059 Accuracy 0.1374
# Epoch 29 Batch 32800 Loss 0.2069 Accuracy 0.1372
# Epoch 29 Batch 32850 Loss 0.2075 Accuracy 0.1371
# Epoch 29 Batch 32900 Loss 0.2082 Accuracy 0.1370
# Epoch 29 Batch 32950 Loss 0.2085 Accuracy 0.1369
# Epoch 29 Batch 33000 Loss 0.2097 Accuracy 0.1366
# Epoch 29 Batch 33050 Loss 0.2107 Accuracy 0.1367
# Epoch 29 Batch 33100 Loss 0.2115 Accuracy 0.1367
# Epoch 29 Batch 33150 Loss 0.2120 Accuracy 0.1366
# Epoch 29 Batch 33200 Loss 0.2130 Accuracy 0.1366
# Epoch 29 Batch 33250 Loss 0.2135 Accuracy 0.1365
# Epoch 29 Batch 33300 Loss 0.2142 Accuracy 0.1364
# Epoch 29 Batch 33350 Loss 0.2149 Accuracy 0.1364
# Epoch 29 Batch 33400 Loss 0.2156 Accuracy 0.1364
# Epoch 29 Batch 33450 Loss 0.2163 Accuracy 0.1363
# Epoch 29 Batch 33500 Loss 0.2167 Accuracy 0.1363
# Epoch 29 Loss 0.2171 Accuracy 0.1363
# Time taken for 1 epoch: 235.3218960762024 secs
#
# Epoch 30 Batch 33550 Loss 0.1971 Accuracy 0.1354
# Epoch 30 Batch 33600 Loss 0.2013 Accuracy 0.1376
# Epoch 30 Batch 33650 Loss 0.2015 Accuracy 0.1382
# Epoch 30 Batch 33700 Loss 0.2019 Accuracy 0.1381
# Epoch 30 Batch 33750 Loss 0.2029 Accuracy 0.1378
# Epoch 30 Batch 33800 Loss 0.2033 Accuracy 0.1375
# Epoch 30 Batch 33850 Loss 0.2043 Accuracy 0.1376
# Epoch 30 Batch 33900 Loss 0.2051 Accuracy 0.1374
# Epoch 30 Batch 33950 Loss 0.2057 Accuracy 0.1374
# Epoch 30 Batch 34000 Loss 0.2062 Accuracy 0.1373
# Epoch 30 Batch 34050 Loss 0.2073 Accuracy 0.1372
# Epoch 30 Batch 34100 Loss 0.2081 Accuracy 0.1373
# Epoch 30 Batch 34150 Loss 0.2088 Accuracy 0.1371
# Epoch 30 Batch 34200 Loss 0.2093 Accuracy 0.1370
# Epoch 30 Batch 34250 Loss 0.2098 Accuracy 0.1370
# Epoch 30 Batch 34300 Loss 0.2101 Accuracy 0.1370
# Epoch 30 Batch 34350 Loss 0.2107 Accuracy 0.1369
# Epoch 30 Batch 34400 Loss 0.2116 Accuracy 0.1369
# Epoch 30 Batch 34450 Loss 0.2121 Accuracy 0.1368
# Epoch 30 Batch 34500 Loss 0.2127 Accuracy 0.1367
# Epoch 30 Batch 34550 Loss 0.2136 Accuracy 0.1367
# Epoch 30 Batch 34600 Loss 0.2141 Accuracy 0.1367
# Epoch 30 Batch 34650 Loss 0.2146 Accuracy 0.1366
# Saving checkpoint for epoch 30 at /content/drive/My Drive/Transformer-master/checkpoints/gpu/model
# Save checkpoints
# Epoch 30 Loss 0.2150 Accuracy 0.1365
# Time taken for 1 epoch: 236.5326771736145 secs
